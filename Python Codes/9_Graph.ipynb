# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# adjacency matrix
import numpy as np
def create_matrix():
    graph = np.zeros((5,5), dtype = int)
    graph[0][2] = 15
    graph[0][4] = 7
    graph[1][2] = 10
    graph[1][3] = 19
    graph[1][4] = 12
    graph[2][0] = 15
    graph[2][1] = 10
    graph[2][3] = 20
    graph[3][1] = 19
    graph[3][2] = 20
    graph[3][4] = 8
    graph[4][0] = 7
    graph[4][1] = 12
    graph[4][3] = 8
    return graph

# %%
graph = create_matrix()
print(graph)
# Out:
# [[ 0  0 15  0  7]
#  [ 0  0 10 19 12]
#  [15 10  0 20  0]
#  [ 0 19 20  0  8]
#  [ 7 12  0  8  0]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, v, w):
        self.v = v
        self.e_w = w
        self.next = None

# %%
def add_edge(graph, u, v, weight):
    new_node = Node(v, weight)
    new_node.next = graph[u]
    graph[u] = new_node
    return

# %%
def create_adjacency_list():
    graph = np.array([None]*5)
    add_edge(graph, 0, 2, 15)
    add_edge(graph, 0, 4, 7)
    add_edge(graph, 1, 2, 10)
    add_edge(graph, 1, 3, 19)
    add_edge(graph, 1, 4, 12)
    add_edge(graph, 2, 0, 15)
    add_edge(graph, 2, 1, 10)
    add_edge(graph, 2, 3, 20)
    add_edge(graph, 3, 1, 19)
    add_edge(graph, 3, 2, 20)
    add_edge(graph, 3, 4, 8)
    add_edge(graph, 4, 0, 7)
    add_edge(graph, 4, 1, 12)
    add_edge(graph, 4, 3, 8)
    return graph

# %%
graph = create_adjacency_list()

# %%
print(graph)
# Out:
# [<__main__.Node object at 0x7ac9c2a62620>
#  <__main__.Node object at 0x7ac9c2a607c0>
#  <__main__.Node object at 0x7ac9c2a624a0>
#  <__main__.Node object at 0x7ac9c2a63610>
#  <__main__.Node object at 0x7ac9c2a60d90>]

# %%
def print_LL(head):
    temp = head
    while temp!= None:
        print(f"connected to {temp.v}, edge weight = {temp.e_w}")
        temp =temp.next
    return

# %%
print_LL(graph[1])
# Out:
# connected to 4, edge weight = 12
# connected to 3, edge weight = 19
# connected to 2, edge weight = 10

# %% [markdown]
# ![graph (2).png](data:image/png;base64,...)
